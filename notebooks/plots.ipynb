# %%
# Adding autoreload will let you edit your package and see the changes without restarting the notebook.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import autocorrelation_plot, lag_plot

# %% [markdown]
# ## Data import

# %%
products_per_week = pd.read_pickle('../data/processed/pickles/products_per_week.pickle')
products_per_week

# %%
prod_id = 1042
subset = products_per_week.loc[products_per_week['product_id'] == prod_id].copy()
subset.set_index('year_week', inplace=True)
subset = subset['products_per_week']
subset
# Out:
# year_week
# 2019_33     3
# 2019_34     9
# 2019_38     1
# 2019_40     4
# 2019_41    19
#            ..
# 2021_48     2
# 2021_49     2
# 2021_50     1
# 2021_51     1
# 2021_53    11
# Name: products_per_week, Length: 75, dtype: int64

# %%
autocorrelation_plot(subset)
plt.show()

# %%
lag_plot(subset, lag=1)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>
